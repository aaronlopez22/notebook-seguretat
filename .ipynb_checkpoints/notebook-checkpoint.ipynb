# %%
print("hola")
# Out:
# hola

# %%
import pandas as pd 
import numpy as np

# %%
celebdict={}

# %%
celebdict['names']=['Eustaqui','Anselma','Protasi','Bonifacia','Anaclet']

# %%
celebdict['age']=[67,51,32,69,35]

# %%
celebdict['gender']=['m','f','f','m','f']

# %%
celebdict['occup']=['actor','everything','singer','actor','singer']

# %% [raw]
# Un DataFrame de Pandas és una estructura de dades de dues dimensions, com una matriu de dues dimensions, o una taula amb files i columnes.

# %%
df = pd.DataFrame(celebdict)

# %% [raw]
# Mostrar df

# %%
print(df)
# Out:
#        names  age gender       occup
# 0   Eustaqui   67      m       actor
# 1    Anselma   51      f  everything
# 2    Protasi   32      f      singer
# 3  Bonifacia   69      m       actor
# 4    Anaclet   35      f      singer

# %% [raw]
# Canviar el tipus de dada de l'atribut edat

# %%
df['age'].dtype
# Out:
# dtype('int64')

# %% [raw]
# Mostrar el tipus de dada dels atributs

# %%
df.dtypes
# Out:
# names       str
# age       int64
# gender      str
# occup       str
# dtype: object

# %% [raw]
# Mostra els 5 primers registres

# %%
df.head()
# Out:
#        names  age gender       occup
# 0   Eustaqui   67      m       actor
# 1    Anselma   51      f  everything
# 2    Protasi   32      f      singer
# 3  Bonifacia   69      m       actor
# 4    Anaclet   35      f      singer

# %% [raw]
# Mostra els 3 primers registres

# %%
df.head(3)
# Out:
#       names  age gender       occup
# 0  Eustaqui   67      m       actor
# 1   Anselma   51      f  everything
# 2   Protasi   32      f      singer

# %% [raw]
# Mostra els 5 últims registres

# %%
df.tail()
# Out:
#        names  age gender       occup
# 0   Eustaqui   67      m       actor
# 1    Anselma   51      f  everything
# 2    Protasi   32      f      singer
# 3  Bonifacia   69      m       actor
# 4    Anaclet   35      f      singer

# %% [raw]
# Mostra els 3 últims registres

# %%
df.tail(3)
# Out:
#        names  age gender   occup
# 2    Protasi   32      f  singer
# 3  Bonifacia   69      m   actor
# 4    Anaclet   35      f  singer

# %% [raw]
# Retorna les dimensions (columnes i registres) del df

# %%
df.shape
# Out:
# (5, 4)

# %% [raw]
# Retorna els atributs

# %%
df.columns.values
# Out:
# <StringArray>
# ['names', 'age', 'gender', 'occup']
# Length: 4, dtype: str

# %% [raw]
# Retorna estadístiques

# %%
df.describe()
# Out:
#              age
# count   5.000000
# mean   50.800000
# std    17.297399
# min    32.000000
# 25%    35.000000
# 50%    51.000000
# 75%    67.000000
# max    69.000000

# %% [raw]
# Retorna un resum del df

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   names   5 non-null      str
#  1   age     5 non-null      int64
#  2   gender  5 non-null      str
#  3   occup   5 non-null      str
# dtypes: int64(1), str(3)
# memory usage: 292.0 bytes
